# %%
import glob
import pickle
import numpy as np

import sys
sys.path.append('..')

from utils import fill_all_channels, contain_invalid

# %%
with open(glob.glob('../../machine-learning/modis/swath/*.pkl')[0], 'rb') as f:
    data = pickle.load(f)

# %%
nan_mask = np.isnan(data)

# %%
for c in range(15):
    print(np.sum(np.isnan(data[c])))
# Out:
# 0
# 0
# 274050
# 0
# 0
# 0
# 0
# 1240
# 0
# 0
# 4480
# 0
# 5
# 0
# 0

# %%
# %matplotlib inline

import matplotlib.pyplot as plt

# %%
data_copy = data.copy()
fill_all_channels(data)
# Out:
# filling channel 2
# filling channel 7
# filling channel 10
# filling channel 12

# %%
print(np.sum(np.isnan(data)))
# Out:
# 0

# %%
plt.figure(figsize=(10, 15))
plt.subplot(131)
plt.imshow(data_copy[2])
plt.subplot(132)
plt.imshow(np.isnan(data_copy[2]))
plt.subplot(133)
plt.imshow(data[2])

# %%
plt.figure(figsize=(10, 15))
plt.subplot(131)
plt.imshow(data_copy[10])
plt.subplot(132)
plt.imshow(np.isnan(data_copy[10]))
plt.subplot(133)
plt.imshow(data[10])
